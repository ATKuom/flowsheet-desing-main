# %%
import win32com.client as win32
import os
cwd = os.getcwd() # get current working directory
os.chdir(cwd) # change to the directory where the script is located
AspenSim = win32.gencache.EnsureDispatch("Apwn.Document") # create an instance of the Aspen Plus application
AspenSim.InitFromArchive2(os.path.abspath("sco2.bkp")) # load the Aspen Plus file
AspenSim.Visible = True # make the Aspen Plus application visible or not
AspenSim.SuppressDialogs = True # suppress any dialog boxes

# %%
# Example for Presentation
import time
a = 0.5 #waiting time in seconds
AspenSim.Tree.Elements("Data").Elements("Blocks").RemoveAll()
AspenSim.Tree.Elements("Data").Elements("Streams").RemoveAll()
AspenSim.Reinit()
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("T1!COMPR")
# Out:
# <win32com.gen_py.Aspen Plus GUI 39.0 Type Library.IHNode instance at 0x1234907233040>

# %%
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("T1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("P(OUT)").Elements.Add("T1OUT")
time.sleep(a) # wait for 1 second to ensure the block is added
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HX1!HEATX")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1HOUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(IN)").Elements.Add("T1OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(OUT)").Elements.Add("HX1HOUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("COOLER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("F(IN)").Elements.Add("HX1HOUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("C1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("P(OUT)").Elements.Add("C1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("CMP1!COMPR")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("F(IN)").Elements.Add("C1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("CMP1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("P(OUT)").Elements.Add("CMP1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("T2!COMPR")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("T2OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T2").Elements("Ports").Elements("F(IN)").Elements.Add("CMP1OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T2").Elements("Ports").Elements("P(OUT)").Elements.Add("T2OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("S1!Fsplit")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("F(IN)").Elements.Add("T2OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT1!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT2!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT2")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("F(IN)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("P(OUT)").Elements.Add("H1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("MIXER1!Mixer")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("H1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(IN)").Elements.Add("S1OUT2")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1COUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(OUT)").Elements.Add("HX1COUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER2!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("F(IN)").Elements.Add("HX1COUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H2OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("P(OUT)").Elements.Add("H2OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("H2OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("MIXOUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("P(OUT)").Elements.Add("MIXOUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER3!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER3").Elements("Ports").Elements("F(IN)").Elements.Add("MIXOUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H3OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER3").Elements("Ports").Elements("P(OUT)").Elements.Add("H3OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("F(IN)").Elements.Add("H3OUT")
# Out:
# <win32com.gen_py.Aspen Plus GUI 39.0 Type Library.IHNode instance at 0x1234932787088>

# %%
import time
a = 0.5 #waiting time in seconds
AspenSim.Tree.Elements("Data").Elements("Blocks").RemoveAll()
AspenSim.Tree.Elements("Data").Elements("Streams").RemoveAll()
AspenSim.Reinit()
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("T1!COMPR")
# Out:
# <win32com.gen_py.Aspen Plus GUI 39.0 Type Library.IHNode instance at 0x1234875032592>

# %%
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("T1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("P(OUT)").Elements.Add("T1OUT")
time.sleep(a) # wait for 1 second to ensure the block is added
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HX1!HEATX")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1HOUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(IN)").Elements.Add("T1OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(OUT)").Elements.Add("HX1HOUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("COOLER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("F(IN)").Elements.Add("HX1HOUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("C1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("P(OUT)").Elements.Add("C1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("CMP1!COMPR")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("F(IN)").Elements.Add("C1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("CMP1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("P(OUT)").Elements.Add("CMP1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("S1!Fsplit")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("F(IN)").Elements.Add("CMP1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT1!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT2!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT2")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("F(IN)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("P(OUT)").Elements.Add("H1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("MIXER1!Mixer")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("H1OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("T2!COMPR")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("T2OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T2").Elements("Ports").Elements("F(IN)").Elements.Add("S1OUT2")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T2").Elements("Ports").Elements("P(OUT)").Elements.Add("T2OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(IN)").Elements.Add("T2OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1COUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(OUT)").Elements.Add("HX1COUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER2!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("F(IN)").Elements.Add("HX1COUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H2OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("P(OUT)").Elements.Add("H2OUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("H2OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("MIXOUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("P(OUT)").Elements.Add("MIXOUT")
time.sleep(a)
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER3!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER3").Elements("Ports").Elements("F(IN)").Elements.Add("MIXOUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H3OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER3").Elements("Ports").Elements("P(OUT)").Elements.Add("H3OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("F(IN)").Elements.Add("H3OUT")
# Out:
# <win32com.gen_py.Aspen Plus GUI 39.0 Type Library.IHNode instance at 0x1234914598288>

# %%
AspenSim.Tree.Elements("Data").Elements("Blocks").RemoveAll()
AspenSim.Tree.Elements("Data").Elements("Streams").RemoveAll()
AspenSim.Reinit()

AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("FEED!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED").Elements("Input").Elements("TEMP").Elements("MIXED").Value = 407.72
AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED").Elements("Input").Elements("PRES").Elements("MIXED").Value = 299.5e5
AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("CO2").Value = 86.67
# # flowsheet = AspenSim.Application.Tree.FindNode("\Data\Blocks")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("T1!COMPR")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("MODEL_TYPE").Value = "TURBINE"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("TYPE").Value = "ISENTROPIC"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("OPT_SPEC").Value = "PRES"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("NPHASE").Value = 2
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("PRES").Value = 78.65e5
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Input").Elements("SEFF").Value = 0.85
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("F(IN)").Elements.Add("FEED")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("T1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("T1").Elements("Ports").Elements("P(OUT)").Elements.Add("T1OUT")

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HX1!HEATX")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Input").Elements("SPEC").Value = "DELT-HOT"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Input").Elements("VALUE").Value = 9.77
#Pressure drop parameters needed to be added
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1HOUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(IN)").Elements.Add("T1OUT")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("H(OUT)").Elements.Add("HX1HOUT")

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("COOLER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("SPEC_OPT").Value = "TP"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("TEMP").Value = 32
#get the pressure from the inlet flow
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("PRES").Value = 77.15e5
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("F(IN)").Elements.Add("HX1HOUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("C1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("P(OUT)").Elements.Add("C1OUT")

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("CMP1!COMPR")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("MODEL_TYPE").Value = "COMPRESSOR"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("TYPE").Value = "ISENTROPIC"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("OPT_SPEC").Value = "PRES"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("NPHASE").Value = 2
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("PRES").Value = 300e5
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Input").Elements("SEFF").Value = 0.82
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("F(IN)").Elements.Add("C1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("CMP1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CMP1").Elements("Ports").Elements("P(OUT)").Elements.Add("CMP1OUT")

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("S1!Fsplit")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("F(IN)").Elements.Add("CMP1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT1!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("S1OUT2!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Ports").Elements("P(OUT)").Elements.Add("S1OUT2")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("S1").Elements("Input").Elements("FRAC").Elements("S1OUT1").Value = 0.01

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER1!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("SPEC_OPT").Value = "TP"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("TEMP").Value = 407.86
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("PRES").Value = 300e5
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("F(IN)").Elements.Add("S1OUT1")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("P(OUT)").Elements.Add("H1OUT")
#First branch ends here
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("MIXER1!Mixer")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("H1OUT")
#second branch starts here if it is a 5 connect the secondary outlet of splitter to the heat exchanger
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(IN)").Elements.Add("S1OUT2")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("HX1COUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HX1").Elements("Ports").Elements("C(OUT)").Elements.Add("HX1COUT")
#second branch ends here connect to the mixer
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("HX1COUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("M1OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("P(OUT)").Elements.Add("M1OUT")

AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER2!Heater")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Input").Elements("SPEC_OPT").Value = "TP"
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Input").Elements("TEMP").Value = 407.72
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Input").Elements("PRES").Value = 299.5e5
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("F(IN)").Elements.Add("M1OUT")
AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H2OUT!MATERIAL")
AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER2").Elements("Ports").Elements("P(OUT)").Elements.Add("H2OUT")




# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("MIXER1!Mixer")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("FEED1!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("TEMP").Elements("MIXED").Value = 298
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("PRES").Elements("MIXED").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("W").Value = 26.31
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EG").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EO").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED1").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("DEG").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("FEED1")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("FEED2!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("TEMP").Elements("MIXED").Value = 298
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("PRES").Elements("MIXED").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("W").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EG").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EO").Value = 27.62
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("FEED2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("DEG").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("FEED2")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("RECYCLE2!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("TEMP").Elements("MIXED").Value = 360.27
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("PRES").Elements("MIXED").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("W").Value = 521.25960426966
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EG").Value = 0.253500051247613
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("EO").Value = 0.86483855131462
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements("RECYCLE2").Elements("Input").Elements("FLOW").Elements("MIXED").Elements("DEG").Value = 1.05869515878343E-07
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("F(IN)").Elements.Add("RECYCLE2")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Input").Elements("NPHASE").Value = 1
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Input").Elements("PHASE").Value = "L"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Input").Elements("PRES").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("M1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("MIXER1").Elements("Ports").Elements("P(OUT)").Elements.Add("M1OUT")

# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("HEATER1!Heater")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("SPEC_OPT").Value = "TP"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("NPHASE").Value = 1
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("PHASE").Value = "L"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("TEMP").Value = 355
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Input").Elements("PRES").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("F(IN)").Elements.Add("M1OUT")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("H1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("HEATER1").Elements("Ports").Elements("P(OUT)").Elements.Add("H1OUT")

# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("PFR1!Rplug")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Ports").Elements("F(IN)").Elements.Add("H1OUT")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("TYPE").Value = "ADIABATIC"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("NPHASE").Value = 1
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("PHASE").Value = "L"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("LENGTH").Value = 8
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("DIAM").Value = 2.185
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Input").Elements("PRES").Value = 2.4
# # Finding the reaction list and adding the reaction
# nodes = AspenSim.Application.Tree.FindNode("/Data/Blocks/PFR1/Input/RXN_ID").Elements
# nodes.InsertRow(1,nodes.Count)
# nodes(nodes.Count-1).Value = "EGR"
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("PFR1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PFR1").Elements("Ports").Elements("P(OUT)").Elements.Add("PFR1OUT")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("CSTR1!RCSTR")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Ports").Elements("F(IN)").Elements.Add("H1OUT")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Input").Elements("SPEC_OPT").Value = "DUTY"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Input").Elements("PRES").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Input").Elements("DUTY").Value = 0.0
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Input").Elements("VOL").Value = 3.75
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Input").Elements("PHASE").Value = "L"
# #Finding the reaction list and adding the reaction
# nodes = AspenSim.Application.Tree.FindNode("/Data/Blocks/CSTR1/Input/RXN_ID").Elements
# nodes.InsertRow(1,nodes.Count)
# nodes(nodes.Count-1).Value = "EGR"
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("R1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1").Elements("Ports").Elements("P(OUT)").Elements.Add("R1OUT")

# for i in range (2,9):
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add(f"CSTR{i}!RCSTR")
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Ports").Elements("F(IN)").Elements.Add(f"R{i-1}OUT")
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Input").Elements("SPEC_OPT").Value = "DUTY"
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Input").Elements("PRES").Value = 2.4
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Input").Elements("DUTY").Value = 0.0
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Input").Elements("VOL").Value = 3.75
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Input").Elements("PHASE").Value = "L"
#     #Finding the reaction list and adding the reaction
#     nodes = AspenSim.Application.Tree.FindNode(f"/Data/Blocks/CSTR{i}/Input/RXN_ID").Elements
#     nodes.InsertRow(1,nodes.Count)
#     nodes(nodes.Count-1).Value = "EGR"
#     AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add(f"R{i}OUT!MATERIAL")
#     AspenSim.Tree.Elements("Data").Elements("Blocks").Elements(f"CSTR{i}").Elements("Ports").Elements("P(OUT)").Elements.Add(f"R{i}OUT")

# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("COOLER1!Heater")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("SPEC_OPT").Value = "TP"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("NPHASE").Value = 1
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("PHASE").Value = "L"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("TEMP").Value = 398
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Input").Elements("PRES").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("F(IN)").Elements.Add(f"R{i}OUT")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("C1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("COOLER1").Elements("Ports").Elements("P(OUT)").Elements.Add("C1OUT")

# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("DISTILL1!RadFrac")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Ports").Elements("F(IN)").Elements.Add("C1OUT")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("CALC_MODE").Value = "EQUILIBRIUM"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("NSTAGE").Value = 12
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("CONDENSER").Value = "TOTAL"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("REBOILER").Value = "KETTLE"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("NO_PHASE").Value = 2
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("CONV_METH").Value = "STANDARD"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("BASIS_RR").Value = 0.024
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("BASIS_B").Value = 26.3
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("FEED_STAGE").Elements("C1OUT").Value = 7
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("FEED_CONVE2").Elements("C1OUT").Value = "ON-STAGE"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Input").Elements("PRES1").Value = 0.71
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("D1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Ports").Elements("LD(OUT)").Elements.Add("D1OUT")
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("PRODUCT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("DISTILL1").Elements("Ports").Elements("B(OUT)").Elements.Add("PRODUCT")

# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements.Add("PUMP1!Pump")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Ports").Elements("F(IN)").Elements.Add("D1OUT")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Input").Elements("OPT_SPEC").Value = "PRES"
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Input").Elements("PRES").Value = 2.4
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Input").Elements("EFF").Value = 0.5
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Input").Elements("DEFF").Value = 0.9
# AspenSim.Tree.Elements("Data").Elements("Streams").Elements.Add("P1OUT!MATERIAL")
# AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("PUMP1").Elements("Ports").Elements("P(OUT)").Elements.Add("P1OUT")




# def explore_tree(node, depth=0):
#     try:
#         print("  " * depth + node.Name)
#         for child in node.Elements:
#             explore_tree(child, depth + 1)
#     except Exception as e:
#         # print("  " * depth + f"[Error accessing node: {e}]")
#         pass


# explore_tree(AspenSim.Tree.Elements("Data").Elements("Blocks").Elements("CSTR1"))

# AspenSim.Run2()
# Out:
# <win32com.gen_py.Aspen Plus GUI 39.0 Type Library.IHNode instance at 0x1234914511568>

# %%
# AspenSim.Run2() # run the simulation
AspenSim.Close(os.path.abspath("sco2.bkp")) # close the Aspen Plus application

# %%
global sim, score_history

def main():
    global sim, score_history
    cwd = os.getcwd()
    sim = Simulation("DME_prod.bkp", cwd)


    env_kwargs = {
            "sim": sim,
            "pure": 0.99, 
            "max_iter": 15, 
            "inlet_specs": [25.0, 1, {"DME": 0, "WATER": 0.2*261.5, "METHANOL": 0.8*261.5}]
        }

    env = Flowsheet(**env_kwargs)

    random_seed = 50
    torch.manual_seed(random_seed)
    np.random.seed(random_seed)
    env.seed(random_seed)
   

    # Hyperparameters
    kwargs = {
        "state_dim": env.observation_space.shape[0], 
        "actions": env.action_space, 
        "env_with_Dead": True,
        "gamma": 0.99, 
        "gae_lambda": 0.95, 
        "policy_clip": 0.2, 
        "n_epochs": 10, 
        "net_width": 64, 
        "lr": 2.5e-4, 
        "l2_reg": 0.5, 
        "batch_size": 64, 
        "entropy_coef": 0.025,
        "adv_normalization": True, 
        "entropy_coef_decay": 0.9
    }


    N = 512 # lenth of long trajectory
    Max_train_steps = int(50e1)
    best_interval = int(10e1)
    score_history = []

    total_steps = 0
    traj_length = 0
    episode = 1
    best_score = -100
    
    
    model = PPO(**kwargs)

    if not os.path.exists('model'): 
        os.mkdir('model')
    
    if not os.path.exists('best_model'): 
        os.mkdir('best_model')
    
    update = 0
    num_updates = Max_train_steps // N
    
    while total_steps < Max_train_steps:
        (observation, sin), done, steps, score = env.reset(), False, 0, 0
        mask_vec = env.action_masks(sin, True)

        '''Interact & trian'''
        while not done:
            steps += 1
            traj_length += 1
            total_steps += 1

            action_d, probs_d, action_c, probs_c = model.select_action(observation, mask_vec)
            action = {
                "discrete": action_d,
                "continuous": action_c}
            
            # Sometimes ASPEN bugs and fails to read information
            try:
                observation_, reward, done, info, sin = env.step(action, sin)

                if (done and steps != env.max_iter):
                    dw = True  #dw: dead and win
                else:
                    dw = False

                model.put_data((observation, action_d, action_c, reward, observation_, probs_d, probs_c, done, dw, mask_vec))
                observation = observation_
                mask_vec = env.action_masks(sin)
                score += reward       

                if traj_length % N == 0:
                    a,b,c = model.train()
                    traj_length = 0
                    update += 1
                    
                    frac = 1.0 - (update - 1.0) / num_updates
                    lrnow = frac * kwargs["lr"]
                    model.actor.optimizer.param_groups[0]["lr"] = lrnow
                    model.critic.optimizer.param_groups[0]["lr"] = lrnow

                    model.save(update)
            
            except:
                print("Error happened when reading data")
                done = True
                
        
        
        
        score_history.append(score)
        avg_score = np.mean(score_history[-100:])

        # Save values of rewards
        f = open('rewards_file', 'a')
        writer = csv.writer(f, lineterminator = '\n')
        writer.writerow([avg_score])
        f.close()


        print('Episode {} total steps {} avg score {:.4f}'.
              format(episode, total_steps, avg_score))
        episode += 1

        ''' best model '''
        if total_steps >= best_interval:
            if score_history[-1] > best_score:
                best_score = score_history[-1]
                model.best_save()


    sim.CloseAspen() 

    
if __name__ == '__main__':
    start_time = time.time()
    try:
        main()
    except:
        print("Error")
        sim.CloseAspen()
    
    x = [i+1 for i in range(len(score_history))]
    plot_learning_curve(x, score_history)

    end_time = time.time()
    final_time = end_time - start_time
    print(final_time)
